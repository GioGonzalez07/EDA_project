# %%
import pandas as pd

# %%
# %store -r  final_merge

# %%
final_merge.head()
# Out:
#          order_id order_date       state region       ship_mode  \
# 0  CA-2017-100006 2017-09-07    New York   East  Standard Class
# 1  CA-2017-100090 2017-07-08  California   West  Standard Class
# 2  CA-2017-100293 2017-03-14     Florida  South  Standard Class
# 3  CA-2017-100328 2017-01-28    New York   East  Standard Class
# 4  CA-2017-100363 2017-04-08     Arizona   West  Standard Class
#
#   ready_to_ship_date pickup_date arrival_scan_date
# 0                NaT         NaT               NaT
# 1                NaT         NaT               NaT
# 2                NaT         NaT               NaT
# 3                NaT         NaT               NaT
# 4                NaT         NaT               NaT

# %%
final_merge['arrival_scan_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5010 entries, 0 to 5009
# Series name: arrival_scan_date
# Non-Null Count  Dtype
# --------------  -----
# 333 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 39.3 KB

# %%
#creating weekdays for arrival scan

final_merge['arrival_scan_date_weekday'] = final_merge['arrival_scan_date'].dt.day_name()

# %%
# creating weekend days for arrival scan dates


final_merge['arrival_scan_date_weekend'] = final_merge['arrival_scan_date_weekday'].isin(['Saturday', 'Sunday']).astype(int)

# %%
final_merge.head()
# Out:
#          order_id order_date       state region       ship_mode  \
# 0  CA-2017-100006 2017-09-07    New York   East  Standard Class
# 1  CA-2017-100090 2017-07-08  California   West  Standard Class
# 2  CA-2017-100293 2017-03-14     Florida  South  Standard Class
# 3  CA-2017-100328 2017-01-28    New York   East  Standard Class
# 4  CA-2017-100363 2017-04-08     Arizona   West  Standard Class
#
#   ready_to_ship_date pickup_date arrival_scan_date arrival_scan_date_weekday  \
# 0                NaT         NaT               NaT                       NaN
# 1                NaT         NaT               NaT                       NaN
# 2                NaT         NaT               NaT                       NaN
# 3                NaT         NaT               NaT                       NaN
# 4                NaT         NaT               NaT                       NaN
#
#    arrival_scan_date_weekend
# 0                          0
# 1                          0
# ...
