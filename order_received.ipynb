# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# %store -r  final_merge

# %%
final_merge['arrival_scan_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5010 entries, 0 to 5009
# Series name: arrival_scan_date
# Non-Null Count  Dtype
# --------------  -----
# 333 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 39.3 KB

# %%
#create new dataframe
order_arriv = pd.DataFrame(final_merge['arrival_scan_date']).copy()
order_arriv= order_arriv.dropna(axis=0, ignore_index=True)

# %%
order_arriv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrival_scan_date  333 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.7 KB

# %%
#creating weekdays for receival 

order_arriv = order_arriv['order_arriv_day'] = order_arriv['arrival_scan_date'].dt.day_name()
# Out:
# /var/folders/vv/4d0yjm893_xcqs8y21lfl70c0000gn/T/ipykernel_21596/2233378103.py:3: SettingWithCopyWarning: modifications to a method of a datetimelike object are not supported and are discarded. Change values on the original.
#   order_arriv = order_arriv['order_arriv_day'] = order_arriv['arrival_scan_date'].dt.day_name()
# /var/folders/vv/4d0yjm893_xcqs8y21lfl70c0000gn/T/ipykernel_21596/2233378103.py:3: SettingWithCopyWarning: modifications to a method of a datetimelike object are not supported and are discarded. Change values on the original.
#   order_arriv = order_arriv['order_arriv_day'] = order_arriv['arrival_scan_date'].dt.day_name()

# %%
# creating weekend days for arrival scan dates


order_arriv['order_arriv_weekend'] = order_arriv['order_arriv_day'].isin(['Saturday', 'Sunday']).astype(int)
# Out:
# /var/folders/vv/4d0yjm893_xcqs8y21lfl70c0000gn/T/ipykernel_21596/2487519899.py:4: SettingWithCopyWarning: modifications to a method of a datetimelike object are not supported and are discarded. Change values on the original.
#   order_arriv['order_arriv_weekend'] = order_arriv['order_arriv_day'].isin(['Saturday', 'Sunday']).astype(int)
# /var/folders/vv/4d0yjm893_xcqs8y21lfl70c0000gn/T/ipykernel_21596/2487519899.py:4: SettingWithCopyWarning: modifications to a method of a datetimelike object are not supported and are discarded. Change values on the original.
#   order_arriv['order_arriv_weekend'] = order_arriv['order_arriv_day'].isin(['Saturday', 'Sunday']).astype(int)

# %%
order_arriv.order_arriv_day.value_counts()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
# ...

# %%
order_arriv.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vv/4d0yjm893_xcqs8y21lfl70c0000gn/T/ipykernel_21596/944043589.py in ?()
# ----> 1 order_arriv.columns
#
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
sns.catplot(x='region', data=order_arrive, kind='count', hue='ship_mode');

# %%
# %store order_arriv
# Out:
# Stored 'order_arriv' (DataFrame)
