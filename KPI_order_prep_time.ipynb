# %%
# %store -r final_merge

# %%
final_merge
# Out:
#             order_id order_date         state   region            ship_mode  \
# 0     CA-2017-100006 2017-09-07      New York     East       Standard Class
# 1     CA-2017-100090 2017-07-08    California     West       Standard Class
# 2     CA-2017-100293 2017-03-14       Florida    South       Standard Class
# 3     CA-2017-100328 2017-01-28      New York     East       Standard Class
# 4     CA-2017-100363 2017-04-08       Arizona     West       Standard Class
# ...              ...        ...           ...      ...                  ...
# 5005  US-2020-168802 2020-11-03    Washington     West  Standard Processing
# 5006  US-2020-169320 2020-07-23       Indiana  Central  Standard Processing
# 5007  US-2020-169488 2020-09-07  Rhode Island     East              Express
# 5008  US-2020-169502 2020-08-28     Wisconsin  Central  Standard Processing
# 5009  US-2020-169551 2020-07-07  Pennsylvania     East              Express
#
#      ready_to_ship_date pickup_date arrival_scan_date
# ...

# %%
final_merge['order_prep_time']=final_merge['ready_to_ship_date'] - final_merge['order_date']
final_merge
# Out:
#             order_id order_date         state   region            ship_mode  \
# 0     CA-2017-100006 2017-09-07      New York     East       Standard Class
# 1     CA-2017-100090 2017-07-08    California     West       Standard Class
# 2     CA-2017-100293 2017-03-14       Florida    South       Standard Class
# 3     CA-2017-100328 2017-01-28      New York     East       Standard Class
# 4     CA-2017-100363 2017-04-08       Arizona     West       Standard Class
# ...              ...        ...           ...      ...                  ...
# 5005  US-2020-168802 2020-11-03    Washington     West  Standard Processing
# 5006  US-2020-169320 2020-07-23       Indiana  Central  Standard Processing
# 5007  US-2020-169488 2020-09-07  Rhode Island     East              Express
# 5008  US-2020-169502 2020-08-28     Wisconsin  Central  Standard Processing
# 5009  US-2020-169551 2020-07-07  Pennsylvania     East              Express
#
# ...
